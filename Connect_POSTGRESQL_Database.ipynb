# %% [markdown]
# # Connect POSTGRESQL Database

# %%
from config import password
from sqlalchemy import create_engine
import pandas.io.sql as psql

# %%
# connection string
DATABASE_URI = f'postgresql://postgres:{password}@localhost:5432/FoodAccess'

# %%
# create engine 
db = create_engine(DATABASE_URI)

# %%
# Connect to PostgreSQL server
dbConnection = db.connect();
dataFrame = psql.read_sql('select * from food_access_main', dbConnection);
dataFrame
# Out:
#        statecountyid  urban  pop2010  ohu2010  povertyrate  \
# 0                  1      1     3668     1311         21.6
# 1                  1      1     3373     1256         15.0
# 2                  1      0     3320     1306         24.1
# 3                  1      1     2891     1188         30.5
# 4                  1      1    10766     4082         15.2
# ...              ...    ...      ...      ...          ...
# 72526           3141      0     3326     1317          9.7
# 72527           3141      1     2665     1154         11.6
# 72528           3141      1     2542     1021         16.3
# 72529           3142      0     3314     1322         17.5
# 72530           3142      1     3894     1699         17.3
#
#        medianfamilyincome  tractlowi  la1and10
# 0                 69521.0     1659.0         1
# 1                 62609.0     1306.0         1
# 2                 49833.0     1463.0         1
# 3                 39875.0     2175.0         1
# 4                 96334.0     2242.0         1
# ...                   ...        ...       ...
# 72526             67254.0      765.0         1
# 72527             64152.0      774.0         0
# 72528             69605.0      789.0         0
# 72529             74500.0      955.0         1
# 72530             76838.0     1095.0         1
#
# [72531 rows x 8 columns]
